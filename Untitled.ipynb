# %% [markdown]
# <a href="https://colab.research.google.com/github/MOHAMEDAYMANAHMAD/testrepo/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Gowalla_cleanCheckins.csv")
df.head()
# Out:
#    user         check-in time   latitude  longitude  location id
# 0     0  2010-10-19T23:55:27Z  30.235909 -97.795140      22847.0
# 1     0  2010-10-18T22:17:43Z  30.269103 -97.749395     420315.0
# 2     0  2010-10-17T23:42:03Z  30.255731 -97.763386     316637.0
# 3     0  2010-10-17T19:26:05Z  30.263418 -97.757597      16516.0
# 4     0  2010-10-16T18:50:42Z  30.274292 -97.740523    5535878.0

# %%
df.shape
# Out:
# (86717, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86717 entries, 0 to 86716
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   user           86717 non-null  int64
#  1   check-in time  86717 non-null  object
#  2   latitude       86717 non-null  float64
#  3   longitude      86716 non-null  float64
#  4   location id    86716 non-null  float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 3.3+ MB

# %%
df.dtypes
# Out:
# user               int64
# check-in time     object
# latitude         float64
# longitude        float64
# location id      float64
# dtype: object

# %%
df.isna().sum()
# Out:
# user             0
# check-in time    0
# latitude         0
# longitude        1
# location id      1
# dtype: int64

# %%
x=df['longitude'].mean()
df['longitude'].replace(np.nan,x,inplace=True)

# %%
df['longitude'].isna().sum()
# Out:
# 0

# %%
y=df['location id'].mean()
df['location id'].replace(np.nan,x,inplace=True)

# %%
df['location id'].isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# user             0
# check-in time    0
# latitude         0
# longitude        0
# location id      0
# dtype: int64

# %%
df['check-in time'] = pd.to_datetime(df['check-in time']).astype(np.int64) / 10 ** 9
print(df['check-in time'].dtype)
# Out:
# float64

# %%
df.dtypes
# Out:
# user               int64
# check-in time    float64
# latitude         float64
# longitude        float64
# location id      float64
# dtype: object

# %%
df.corr()
# Out:
#                    user  check-in time  latitude  longitude  location id
# user           1.000000      -0.048446 -0.008819  -0.006713     0.027081
# check-in time -0.048446       1.000000  0.093491  -0.015760     0.344370
# latitude      -0.008819       0.093491  1.000000   0.189247     0.059500
# longitude     -0.006713      -0.015760  0.189247   1.000000     0.035041
# location id    0.027081       0.344370  0.059500   0.035041     1.000000

# %%
df.describe()
# Out:
#               user  check-in time      latitude     longitude   location id
# count  86717.00000   8.671700e+04  86717.000000  86717.000000  8.671700e+04
# mean     162.82993   1.272005e+09     36.225906    -98.162307  3.399102e+05
# std       79.41882   9.668483e+06      7.945877     35.450783  6.057981e+05
# min        0.00000   1.233725e+09    -48.224670   -176.308594 -9.816231e+01
# 25%      110.00000   1.264775e+09     30.291617   -122.158741  2.691900e+04
# 50%      174.00000   1.271285e+09     37.406011    -97.750427  1.048020e+05
# 75%      226.00000   1.280693e+09     39.097104    -94.653927  4.247900e+05
# max      302.00000   1.287722e+09     63.403437    177.452904  5.915990e+06
